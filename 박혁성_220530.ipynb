# %%
import pandas as pd
credit_path = "https://raw.githubusercontent.com/saerannn/OTT-Platforms-Analytics/main/src/data/ott_credits.csv?token=GHSAT0AAAAAABVCSFTITI5PGCOMRBIMZE2SYUUQPWA" 
pd.read_csv(credit_path)
# Out:
#         person_id         id             name                character  \
# 0            3748    tm84618   Robert De Niro            Travis Bickle
# 1           14658    tm84618     Jodie Foster            Iris Steensma
# 2            7064    tm84618    Albert Brooks                      Tom
# 3            3739    tm84618    Harvey Keitel  Matthew 'Sport' Higgins
# 4           48933    tm84618  Cybill Shepherd                    Betsy
# ...           ...        ...              ...                      ...
# 267697    1938589  tm1054116    Sangam Shukla                   Madhav
# 267698    1938565  tm1054116     Vijay Thakur            Sanjay Thakur
# 267699     728899  tm1054116    Vanya Wellens                  Budhiya
# 267700    1938620  tm1054116     Vishwa Bhanu                    Gissu
# 267701    1938620  tm1054116     Vishwa Bhanu                      NaN
#
#             role      OTT
# 0          ACTOR  Nexflix
# 1          ACTOR  Nexflix
# 2          ACTOR  Nexflix
# ...

# %%
title_path = "https://raw.githubusercontent.com/saerannn/OTT-Platforms-Analytics/main/src/data/ott_title.csv?token=GHSAT0AAAAAABVCSFTJMC4SLOQSW42R5VE4YUUQRIA" 
pd.read_csv(title_path)
# Out:
#         title_id                                title   type  \
# 0       ts300399  Five Came Back: The Reference Films   SHOW
# 1        tm84618                          Taxi Driver  MOVIE
# 2       tm127384      Monty Python and the Holy Grail  MOVIE
# 3        tm70993                        Life of Brian  MOVIE
# 4       tm190788                         The Exorcist  MOVIE
# ...          ...                                  ...    ...
# 20031   tm510327                         Lily Is Here  MOVIE
# 20032  tm1079144      Jay Nog: Something from Nothing  MOVIE
# 20033   tm847725                              Chasing  MOVIE
# 20034  tm1054116                             Baikunth  MOVIE
# 20035   ts275838                     Waking Up Eighty   SHOW
#
#                                              description  release_year  \
# 0      This collection includes 12 World War II-era p...          1945
# 1      A mentally unstable Vietnam War veteran works ...          1976
# ...
